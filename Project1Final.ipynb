# %% [markdown]
# # Project1

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %% [markdown]
# ### 1. Get the Metadata from the above files.

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# ### 2. Get the row names from the above files.

# %%
np.array(df.index)
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
np.array(df1.index)
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# ### 3. Change the column name from any of the above file.

# %%
df.rename(columns = {'Indicator':'Indicator_id'}, inplace=False) 
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 4. Change the column name from any of the above file and store the changes made permanently.

# %%
df.rename(columns = {'Indicator':'Indicator_id'}, inplace=True) 
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 5. Change the names of multiple columns.

# %%
df.rename(columns = {'PUBLISH STATES':'Publication Status','WHO region':'WHO Region'}, inplace=True)

# %% [markdown]
# ### 6. Arrange values of a particular column in ascending order.

# %%
df.sort_values('Year',ascending=True)
# Out:
#                                          Indicator_id Publication Status  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %% [markdown]
# ### 7. Arrange multiple column values in ascending order.

# %%
df.sort_values(['Indicator_id','Country','Year','WHO Region','Publication Status'],ascending=True).head(3)
# Out:
#                                          Indicator_id Publication Status  \
# 2798  Healthy life expectancy (HALE) at birth (years)          Published
# 3363  Healthy life expectancy (HALE) at birth (years)          Published
# 4456  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year             WHO Region World Bank income group      Country  \
# 2798  2000  Eastern Mediterranean              Low-income  Afghanistan
# 3363  2000  Eastern Mediterranean              Low-income  Afghanistan
# 4456  2000  Eastern Mediterranean              Low-income  Afghanistan
#
#              Sex  Display Value  Numeric  Low  High  Comments
# 2798        Male             45     45.0  NaN   NaN       NaN
# 3363  Both sexes             45     45.0  NaN   NaN       NaN
# 4456      Female             45     45.0  NaN   NaN       NaN

# %%
df_n = df.loc[:,['Indicator_id','Country','Year','WHO Region','Publication Status']]
df_n.sort_index().head(3)
# Out:
#                         Indicator_id  Country  Year WHO Region  \
# 0   Life expectancy at birth (years)  Andorra  1990     Europe
# 1   Life expectancy at birth (years)  Andorra  2000     Europe
# 2  Life expectancy at age 60 (years)  Andorra  2012     Europe
#
#   Publication Status
# 0          Published
# 1          Published
# 2          Published

# %% [markdown]
# ### 8. Make country as the first column of the dataframe.

# %%
df.columns
# Out:
# Index(['Indicator_id', 'Publication Status', 'Year', 'WHO Region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df.loc[:,['Country','Indicator_id', 'Publication Status', 'Year', 'WHO Region',
       'World Bank income group',  'Sex', 'Display Value', 'Numeric',
       'Low', 'High', 'Comments']].head(3)
# Out:
#    Country                       Indicator_id Publication Status  Year  \
# 0  Andorra   Life expectancy at birth (years)          Published  1990
# 1  Andorra   Life expectancy at birth (years)          Published  2000
# 2  Andorra  Life expectancy at age 60 (years)          Published  2012
#
#   WHO Region World Bank income group         Sex  Display Value  Numeric  Low  \
# 0     Europe             High-income  Both sexes             77     77.0  NaN
# 1     Europe             High-income  Both sexes             80     80.0  NaN
# 2     Europe             High-income      Female             28     28.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN

# %% [markdown]
# ### 9. Get the column array using a variable

# %%
np.array(df["WHO Region"])
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %% [markdown]
# ### 10. Get the subset rows 11, 24, 37

# %%
df.iloc[[11,24,37],:]
# Out:
#                          Indicator_id Publication Status  Year  \
# 11   Life expectancy at birth (years)          Published  2012
# 24  Life expectancy at age 60 (years)          Published  2012
# 37  Life expectancy at age 60 (years)          Published  2012
#
#          WHO Region World Bank income group            Country     Sex  \
# 11           Europe             High-income            Austria  Female
# 24  Western Pacific             High-income  Brunei Darussalam  Female
# 37           Europe             High-income             Cyprus  Female
#
#     Display Value  Numeric  Low  High  Comments
# 11             83     83.0  NaN   NaN       NaN
# 24             21     21.0  NaN   NaN       NaN
# 37             26     26.0  NaN   NaN       NaN

# %% [markdown]
# ### 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
df.drop([5,12,23,56]).head()
# Out:
#                         Indicator_id Publication Status  Year  \
# 0   Life expectancy at birth (years)          Published  1990
# 1   Life expectancy at birth (years)          Published  2000
# 2  Life expectancy at age 60 (years)          Published  2012
# 3  Life expectancy at age 60 (years)          Published  2000
# 4   Life expectancy at birth (years)          Published  2012
#
#               WHO Region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ### Load datasets from CSV

# %%
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
products.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# ### 12. Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

# %%
pd.merge(transactions, users, how='left',on='UserID').head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08

# %% [markdown]
# ### 13. Which transactions have a UserID not in users?

# %%
sol1

# %% [markdown]
# ### 14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join)

# %%
pd.merge(transactions, users, how='inner',on='UserID').head(10)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# ### 15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join)

# %%
usr_trans = pd.merge(transactions, users, how='outer',on='UserID')
usr_trans.head(15)
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %% [markdown]
# ### 16. Determine which sessions occurred on the same day each user registered

# %%
sess_us=pd.merge(sessions, users, how='inner',on='UserID')
sess_us.head(5)
# Out:
#    SessionID SessionDate  UserID      User  Gender  Registered   Cancelled
# 0          1  2010-01-05       2     Pedro    male  2010-08-01  2010-08-08
# 1          2  2010-08-01       2     Pedro    male  2010-08-01  2010-08-08
# 2          3  2010-11-25       2     Pedro    male  2010-08-01  2010-08-08
# 3          4  2011-09-21       5  Benjamin    male  2010-11-25         NaN
# 4          5  2011-10-19       4   Brielle  female  2013-07-17         NaN

# %%
sess_us[sess_us['SessionDate']==sess_us['Registered']].head(4)
# Out:
#    SessionID SessionDate  UserID     User  Gender  Registered   Cancelled
# 1          2  2010-08-01       2    Pedro    male  2010-08-01  2010-08-08
# 7          9  2013-07-17       4  Brielle  female  2013-07-17         NaN

# %%
pd.merge(sessions,users,how='inner',left_on=['UserID','SessionDate'],right_on=['UserID','Registered'])
sess_us.loc[sess_us['SessionDate']==sess_us['Registered'],:]
# Out:
#    SessionID SessionDate  UserID     User  Gender  Registered   Cancelled
# 1          2  2010-08-01       2    Pedro    male  2010-08-01  2010-08-08
# 7          9  2013-07-17       4  Brielle  female  2013-07-17         NaN

# %% [markdown]
# ### 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
#pd.merge(users, products, how='outer',on='key')
users['Key'] = 0
products['Key'] = 0
posDS = pd.merge(users,products, on = 'Key')
#posDS.head(12)
posDS=posDS.loc[:,["UserID", "ProductID"]]
posDS.head(12)
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2

# %% [markdown]
# ### 18. Determine how much quantity of each product was purchased by each user

# %%
#trans table
users['Key'] = 0
transactions['Key'] = 0
QntUsr = pd.merge(users,transactions, on = 'Key')
#QntUsr = pd.merge(users,transactions, how='inner',on='UserID')
#QntUsr.head(12)
#QntUsr= transactions.loc[:,["UserID", "ProductID","Quantity"]]
#QntUsr.sort_values(["UserID","ProductID"])
#posDS['Key']=0
#transactions['Key'] = 0
#QntUsr = pd.merge(products,transactions, on = 'Key')
QntUsr= QntUsr.loc[:,["UserID_x", "ProductID","Quantity"]]
QntUsr.sort_values("ProductID")
QntUsr.head()
# Out:
#    UserID_x  ProductID  Quantity
# 0         1          2         1
# 1         1          4         1
# 2         1          3         1
# 3         1          2         3
# 4         1          4         1

# %% [markdown]
# ### 19. For each user, get each possible pair of pair
# transactions (TransactionID1, TransacationID2)

# %%
new_dT=transactions.join(products,on=['TransactionID'],how='outer',lsuffix='_x',rsuffix='_y')
new_dT.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID_x  Quantity  ProductID_y  \
# 0              1      2010-08-21     7.0          2.0       1.0          2.0
# 1              2      2011-05-26     3.0          4.0       1.0          3.0
# 2              3      2011-06-16     3.0          3.0       1.0          4.0
# 3              4      2012-08-26     1.0          2.0       3.0          5.0
# 4              5      2013-06-06     2.0          4.0       1.0          NaN
#
#   Product  Price
# 0       B  33.04
# 1       C  10.65
# 2       D  10.02
# 3       E  29.66
# 4     NaN    NaN

# %% [markdown]
# ### 20. Join each user to his/her first occuring transaction in the transactions table

# %%
new_usr = pd.merge(users,transactions, on = 'UserID')
new_usr.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN              4
# 1       2     Pedro    male  2010-08-01  2010-08-08              5
# 2       2     Pedro    male  2010-08-01  2010-08-08              6
# 3       3  Caroline  female  2012-10-23  2016-06-07              2
# 4       3  Caroline  female  2012-10-23  2016-06-07              3
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26          2         3
# 1      2013-06-06          4         1
# 2      2013-12-23          5         6
# 3      2011-05-26          4         1
# 4      2011-06-16          3         1

# %% [markdown]
# ### 21. Test to see if we can drop columns

# %%
new_usr.drop(["User"]).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-58-1313b63692ec> in <module>
# ----> 1 new_usr.drop(["User"]).head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# -> 3780                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
# ...

# %% [markdown]
# #### Code with Output :

# %%
my_columns = list(new_usr.columns)
#my_columns['UserID','User','Gender','Registered','Cancelled','TransactionID','TransactionDate','ProductID', 'Quantity']
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
list(new_usr.dropna(thresh=int(new_usr.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
#set threshold to drop NAs
usr_columns = list(users.dropna(thresh=int(users.shape[0] * .9), axis=1).columns)
usr_columns
#['UserID', 'User', 'Gender', 'Registered']
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
missing_info = list(new_usr.columns[usr_trans.isnull().any()]) 
missing_info
#missing_info['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
#for col in missing_info:
Num_missing = users[users['Cancelled'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('Cancelled', Num_missing))
# Out:
# number missing for column Cancelled: 6

# %%
Num_missing = usr_trans[usr_trans['TransactionID'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('TransactionID', Num_missing))
# Out:
# number missing for column TransactionID: 2

# %%
Num_missing = usr_trans[usr_trans['TransactionDate'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('TransactionDate', Num_missing))
# Out:
# number missing for column TransactionDate: 2

# %%
Num_missing = usr_trans[usr_trans['ProductID'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('ProductID', Num_missing))
# Out:
# number missing for column ProductID: 2

# %%
Num_missing = usr_trans[usr_trans['Quantity'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('Quantity', Num_missing))
# Out:
# number missing for column Quantity: 2

# %%
#for col in missing_info:
num_missing = users[users['Cancelled'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('Cancelled', num_missing))  #count of missing data
#for Cancelled in missing_info:
percent_missing = users[users['Cancelled'].isnull() == True].shape[0] / users.shape[0] 
print('percent missing for column {}: {}'.format( 'Cancelled',percent_missing))
# Out:
# number missing for column Cancelled: 3
# percent missing for column Cancelled: 0.6

# %%
#for col in missing_info:
num_missing = usr_trans[usr_trans['TransactionID'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format(' TransactionID', num_missing))  #count of missing data
#for Cancelled in missing_info:
percent_missing = usr_trans[usr_trans['TransactionID'].isnull() == True].shape[0] / usr_trans.shape[0] 
print('percent missing for column {}: {}'.format( 'TransactionID',percent_missing))
# Out:
# number missing for column  TransactionID: 2
# percent missing for column TransactionID: 0.16666666666666666

# %%
#for col in missing_info:
num_missing = usr_trans[usr_trans['TransactionDate'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('TransactionDate', num_missing))  #count of missing data
#for Cancelled in missing_info:
percent_missing = usr_trans[usr_trans['TransactionDate'].isnull() == True].shape[0] / usr_trans.shape[0] 
print('percent missing for column {}: {}'.format( 'TransactionDate',percent_missing))
# Out:
# number missing for column TransactionDate: 2
# percent missing for column TransactionDate: 0.16666666666666666

# %%
#for col in missing_info:
num_missing = usr_trans[usr_trans['ProductID'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('ProductID', num_missing))  #count of missing data
#for Cancelled in missing_info:
percent_missing = usr_trans[usr_trans['ProductID'].isnull() == True].shape[0] / usr_trans.shape[0] 
print('percent missing for column {}: {}'.format( 'ProductID',percent_missing))
# Out:
# number missing for column ProductID: 2
# percent missing for column ProductID: 0.16666666666666666

# %%
#for col in missing_info:
num_missing = usr_trans[usr_trans['Quantity'].isnull() == True].shape[0] 
print('number missing for column {}: {}'.format('Quantity', num_missing))  #count of missing data
#for Cancelled in missing_info:
percent_missing = usr_trans[usr_trans['Quantity'].isnull() == True].shape[0] / usr_trans.shape[0] 
print('percent missing for column {}: {}'.format( 'Quantity',percent_missing))
# Out:
# number missing for column Quantity: 2
# percent missing for column Quantity: 0.16666666666666666

# %% [markdown]
# # Thank you!!!
